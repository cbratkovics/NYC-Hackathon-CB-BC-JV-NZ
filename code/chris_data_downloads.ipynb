# %% [markdown]
# # [2015 Street Tree Census - Tree Data](https://dev.socrata.com/foundry/data.cityofnewyork.us/uvpi-gqnh)

# %%
import pandas as pd
import numpy as np
from sodapy import Socrata
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
MyAppToken = 'insert_app_token_here'

# %%
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", MyAppToken, 
                 username="insert_user_name_here", 
                 password="insert_password_here")

# %%
# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("uvpi-gqnh", limit=683788)

# Convert to pandas DataFrame
tree_df = pd.DataFrame.from_records(results)

# %%
tree_df.head()
# Out:
#              address         bbl      bin block_id  boro_ct borocode  \
# 0  108-005 70 AVENUE  4022210001  4052307   348711  4073900        4
# 1   147-074 7 AVENUE  4044750045  4101931   315986  4097300        4
# 2  390 MORGAN AVENUE  3028870001  3338310   218365  3044900        3
# 3  1027 GRAND STREET  3029250001  3338342   217969  3044900        3
# 4       603 6 STREET  3010850052  3025654   223043  3016500        3
#
#    boroname brch_light brch_other brch_shoe  ... tree_dbh tree_id trnk_light  \
# 0    Queens         No         No        No  ...        3  180683         No
# 1    Queens         No         No        No  ...       21  200540         No
# 2  Brooklyn         No         No        No  ...        3  204026         No
# 3  Brooklyn         No         No        No  ...       10  204337         No
# 4  Brooklyn         No         No        No  ...       21  189565         No
#
#   trnk_other trunk_wire         user_type         x_sp         y_sp  \
# ...

# %%
tree_df.shape
# Out:
# (683788, 45)

# %%
tree_df.to_csv("../data/original_tree.csv",index=False)

# %% [markdown]
# # [DOHMH Dog Bite Data](https://dev.socrata.com/foundry/data.cityofnewyork.us/rsgh-akpg)

# %%
results = client.get("rsgh-akpg", limit=10300)

# Convert to pandas DataFrame
dog_bite_df = pd.DataFrame.from_records(results)

# %%
dog_bite_df.head()
# Out:
#    age   borough                               breed               dateofbite  \
# 0    3  Brooklyn                    Poodle, Standard  2015-01-02T00:00:00.000
# 1  NaN  Brooklyn                               HUSKY  2015-01-02T00:00:00.000
# 2  NaN  Brooklyn                                 NaN  2015-01-02T00:00:00.000
# 3    6  Brooklyn  American Pit Bull Terrier/Pit Bull  2015-01-01T00:00:00.000
# 4    1  Brooklyn  American Pit Bull Terrier/Pit Bull  2015-01-03T00:00:00.000
#
#   gender  spayneuter species uniqueid zipcode
# 0      M        True     DOG        1   11238
# 1      U       False     DOG        2   11249
# 2      U       False     DOG        3     NaN
# 3      M       False     DOG        4   11221
# 4      M       False     DOG        5   11207

# %%
dog_bite_df.to_csv("../data/original_dog_bite.csv",index=False)

# %% [markdown]
# # [NYC Dog Licensing Dataset](https://dev.socrata.com/foundry/data.cityofnewyork.us/nu7n-tubp)

# %%
results = client.get("nu7n-tubp", limit=122000)

# Convert to pandas DataFrame
dog_lic_df = pd.DataFrame.from_records(results)

# %%
dog_lic_df.head()
# Out:
#                animalbirth animalgender animalname borough  \
# 0  2013-05-01T00:00:00.000            F    BONITA   Queens
# 1  2014-05-01T00:00:00.000            M      ROCKY  Queens
# 2  2010-07-01T00:00:00.000            M      BULLY  Queens
# 3  2005-02-01T00:00:00.000            M      COCO   Queens
# 4  2012-09-01T00:00:00.000            F       SKI   Queens
#
#                             breedname censustract2010 citycouncildistrict  \
# 0                             Unknown             208                  28
# 1       Labrador Retriever Crossbreed          100801                  31
# 2  American Pit Bull Terrier/Pit Bull              98                  28
# 3                  Labrador Retriever             964                  31
# 4  American Pit Bull Terrier/Pit Bull          100802                  31
#
#   communitydistrict congressionaldistrict       licenseexpireddate  \
# 0               412                     5  2017-11-15T00:00:00.000
# ...

# %%
dog_lic_df.to_csv("../data/original_dog_license.csv",index=False)
